# %% [markdown]
# ### <span style="color: red"> Task 1:</span> Some errors are presented in the code below. Can you identify and corret them?

# %%
import os
import csv

current_dir = os.getcwd()
filename = current_dir + '\\E1_T1.csv' # added \\ to correct filepath
with open(filename, 'r', newline='') as f: # added ' after newline
    csv_file = csv.reader(f)
    data = list(csv_file)
sentence=''
for word in data:
    sentence = sentence + ' '+ str(word) # casted word to string to correct type mismatch
print(sentence)
print(type(sentence))
# Out:
#  ['This', 'task', 'is', 'too', 'simple', ',', 'I', 'want', 'more', 'challenges']
# <class 'str'>

# %% [markdown]
# ### <span style="color: red"> Task 2:</span> Who has the most runner-up (i.e., second place) finishes in the histroy of NHL? Create a table with the teams and their runner-up finishes. The table must contain the the following columns:
#
# -Team
#
# -Total number of runner-up finishes
#
# -Years [list of the years they finished as a runner-up]
#
# You have to use Jupyter for the practice and produce a notebook with good readability.

# %% [markdown]
# ### <span style="color: blue"> Solution:</span>

# %%
import pandas as pd

# %%
# Import data
file = "Stanely_cup_winners_by_year.xlsx"
df = pd.read_excel(file)

# %%
# Visuzlize structure of data
df.head()
# Out:
#    Year                 Team             Runner up
# 0  2020  Tampa Bay Lightning          Dallas Stars
# 1  2019      St. Louis Blues         Boston Bruins
# 2  2018  Washington Capitals  Vegas Golden Knights
# 3  2017  Pittsburgh Penguins   Nashville Predators
# 4  2016  Pittsburgh Penguins       San Jose Sharks

# %%
# Create new dataframe to store how many times each team was a runner up
df2 = pd.DataFrame()

# %%
# Get all teams who were runner ups

# Learnt .unique() from
# https://stackoverflow.com/questions/32072076/find-the-unique-values-in-a-column-and-then-sort-them
df2['Team'] = df['Runner up'].unique()

# %%
df2.head()
# Out:
#                    Team
# 0          Dallas Stars
# 1         Boston Bruins
# 2  Vegas Golden Knights
# 3   Nashville Predators
# 4       San Jose Sharks

# %%
runner_up_counts = pd.DataFrame(df.groupby(['Runner up']).count()['Team'])

# %%
runner_up_counts.head()
# Out:
#                      Team
# Runner up
# Boston Bruins          14
# Buffalo Sabres          2
# Calgary Flames          2
# Calgary Tigers          1
# Carolina Hurricanes     1

# %%
# Merged df2 with runner up counts 
# Learnt about pd.merge() from:
# https://towardsdatascience.com/all-the-pandas-merge-you-should-know-for-combining-datasets-526b9ecaf184
df2 = pd.merge(df2, runner_up_counts, left_on='Team', right_on='Runner up')

# %%
df2.head()
# Out:
#                  Team_x  Team_y
# 0          Dallas Stars       2
# 1         Boston Bruins      14
# 2  Vegas Golden Knights       1
# 3   Nashville Predators       1
# 4       San Jose Sharks       1

# %%
# Renaming column titles of runner-up history dataframe
df2.columns = ["Team", "Total number of runner-up finishes"]

# %%
# List years each team was a runner-up by grouping by runner up
"""
Learnt this method of indexing what .groupby() returns by year and applying .apply() to 
# apply the list() function row by row from
# https://stackoverflow.com/questions/22219004/how-to-group-dataframe-rows-into-list-in-pandas-groupby
"""
years_as_runner_up = df.groupby('Runner up')['Year'].apply(list)
years_as_runner_up = pd.DataFrame(years_as_runner_up)

# Adding index column 
# .reset_index() method from 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html
years_as_runner_up = years_as_runner_up.reset_index()

# %%
years_as_runner_up.head()
# Out:
#              Runner up                                               Year
# 0        Boston Bruins  [2019, 2013, 1990, 1988, 1978, 1977, 1974, 195...
# 1       Buffalo Sabres                                       [1999, 1975]
# 2       Calgary Flames                                       [2004, 1986]
# 3       Calgary Tigers                                             [1924]
# 4  Carolina Hurricanes                                             [2002]

# %%
# Merge df2 and years_as_runner_up to attach list of years each team was a runner up 
# to the team name
team_years_runner_up = pd.merge(df2, years_as_runner_up, left_on="Team", right_on='Runner up')

# %%
df2['Years'] = team_years_runner_up['Year']

# %%
df2
# Out:
#                        Team  Total number of runner-up finishes  \
# 0              Dallas Stars                                   2
# 1             Boston Bruins                                  14
# 2      Vegas Golden Knights                                   1
# 3       Nashville Predators                                   1
# 4           San Jose Sharks                                   1
# 5       Tampa Bay Lightning                                   1
# 6          New York Rangers                                   7
# 7         New Jersey Devils                                   2
# 8         Vancouver Canucks                                   3
# 9       Philadelphia Flyers                                   6
# 10        Detroit Red Wings                                  13
# 11      Pittsburgh Penguins                                   1
# 12          Ottawa Senators                                   2
# 13          Edmonton Oilers                                   2
# 14           Calgary Flames                                   2
# 15  Mighty Ducks of Anaheim                                   1
# 16      Carolina Hurricanes                                   1
# 17           Buffalo Sabres                                   2
# 18      Washington Capitals                                   1
# 19         Florida Panthers                                   1
# 20        Los Angeles Kings                                   1
# 21       Chicago Blackhawks                                   6
# 22    Minnesota North Stars                                   2
# 23       Montreal Canadiens                                   9
# 24       New York Islanders                                   1
# 25          St. Louis Blues                                   3
# 26      Toronto Maple Leafs                                   8
# 27      Chicago Black Hawks                                   1
# 28         Montreal Maroons                                   1
# 29         Victoria Cougars                                   2
# 30           Calgary Tigers                                   1
# 31         Edmonton Eskimos                                   1
# 32   Vancouver Millionaires                                   3
# 33    Seattle Metropolitans                                   1
# 34        Portland Rosebuds                                   1
# 35            Sydney Miners                                   1
# 36        Moncton Victories                                   1
# 37     Port Arthur Bearcats                                   1
#
#                                                 Years
# 0                                        [2020, 2000]
# 1   [2019, 2013, 1990, 1988, 1978, 1977, 1974, 195...
# 2                                              [2018]
# 3                                              [2017]
# 4                                              [2016]
# 5                                              [2015]
# 6          [2014, 1979, 1972, 1950, 1937, 1932, 1929]
# 7                                        [2012, 2001]
# 8                                  [2011, 1994, 1982]
# 9                [2010, 1997, 1987, 1985, 1980, 1976]
# 10  [2009, 1995, 1966, 1964, 1963, 1961, 1956, 194...
# 11                                             [2008]
# 12                                       [2007, 1915]
# 13                                       [2006, 1983]
# 14                                       [2004, 1986]
# 15                                             [2003]
# 16                                             [2002]
# 17                                       [1999, 1975]
# 18                                             [1998]
# 19                                             [1996]
# 20                                             [1993]
# 21               [1992, 1973, 1971, 1965, 1962, 1944]
# 22                                       [1991, 1981]
# 23  [1989, 1967, 1955, 1954, 1952, 1951, 1947, 192...
# 24                                             [1984]
# 25                                 [1970, 1969, 1968]
# 26   [1960, 1959, 1940, 1939, 1938, 1936, 1935, 1933]
# 27                                             [1931]
# 28                                             [1928]
# 29                                       [1926, 1914]
# 30                                             [1924]
# 31                                             [1923]
# 32                                 [1922, 1921, 1918]
# 33                                             [1920]
# 34                                             [1916]
# 35                                             [1913]
# 36                                             [1912]
# 37                                             [1911]

# %% [markdown]
# The Boston Bruins have the most runner-up finishes

# %% [markdown]
# ### <span style="color: red"> Task 3:</span> With the help of matminer, 1. Retrive the 'steel_strength' dataset into a dataframe and clean your dataset (i.e., do some basic data exploration and analysis work on your data. For instance, check the statistics of the dataset, check for NaNs, drop duplicated data entries etc. It is alway the first thing to do before you start working on a dataset.) if needed; 2. Featurize the compositions of the materials; and 3. Perform correlation analysis and drop feature(s) with a coefficient greater than abs(0.8) from your dataframe.

# %% [markdown]
# ### <span style="color: blue"> Solution:</span>

# %%
import matminer
from matminer.datasets import load_dataset
#matminer.datasets.get_available_datasets() #you can check what datasets are available with this line

# %%
steel_data = load_dataset('steel_strength')

# %%
steel_data.head()
# Out:
#                                              formula     c    mn    si     cr  \
# 0  Fe0.620C0.000953Mn0.000521Si0.00102Cr0.000110N...  0.02  0.05  0.05   0.01
# 1  Fe0.623C0.00854Mn0.000104Si0.000203Cr0.147Ni0....  0.18  0.01  0.01  13.44
# 2  Fe0.625Mn0.000102Si0.000200Cr0.0936Ni0.129Mo0....  0.00  0.01  0.01   8.67
# 3  Fe0.634C0.000478Mn0.000523Si0.00102Cr0.000111N...  0.01  0.05  0.05   0.01
# 4  Fe0.636C0.000474Mn0.000518Si0.00101Cr0.000109N...  0.01  0.05  0.05   0.01
#
#       ni    mo     v     n    nb     co     w    al    ti  yield strength  \
# 0  19.70  2.95  0.01  0.00  0.01  15.00  0.00  0.15  1.55          2411.5
# 1   0.01  3.01  0.46  0.04  0.01  19.46  2.35  0.04  0.00          1123.1
# 2  13.45  0.82  0.01  0.00  0.01  13.90  0.00  0.39  0.57          1736.3
# 3  17.70  3.95  0.01  0.00  0.01  15.00  0.00  0.13  1.47          2487.3
# 4  19.40  1.45  0.01  0.00  0.01  14.90  0.00  0.13  1.55          2249.6
#
#    tensile strength  elongation
# 0            2473.5         7.0
# 1            1929.2         8.0
# 2            1871.8         NaN
# 3            2514.9         9.0
# 4            2315.0         8.5

# %% [markdown]
# Checking for NaN and duplicate rows:

# %%
# Checking for NaNs per column
# https://stackoverflow.com/questions/56261130/count-all-nans-in-a-pandas-dataframe
steel_data.isna().sum(axis=0)
# Out:
# formula             0
# c                   0
# mn                  0
# si                  0
# cr                  0
# ni                  0
# mo                  0
# v                   0
# n                   0
# nb                  0
# co                  0
# w                   0
# al                  0
# ti                  0
# yield strength      0
# tensile strength    0
# elongation          9
# dtype: int64

# %% [markdown]
# There are 9 formulae with NaN elongation values. These rows will be discarded

# %%
steel_data = steel_data.dropna()

# %%
# Checking for duplicate rows
# Using same methodology as checking for NaN but used .duplicated()
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html
steel_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no repeated alloys in the data set.

# %%
from matminer.featurizers.conversions import StrToComposition
from matminer.featurizers.composition import ElementFraction
from tqdm.autonotebook import tqdm

# %%
# Get list of elements in each formula
steel_data_featurized = StrToComposition().featurize_dataframe(steel_data, "formula")
# Out:
# StrToComposition:   0%|          | 0/303 [00:00<?, ?it/s]

# %%
# Get element fraction of each alloy in steel_data
steel_data_featurized = ElementFraction().featurize_dataframe(steel_data_featurized, "composition")
# Out:
# ElementFraction:   0%|          | 0/303 [00:00<?, ?it/s]

# %%
copy_steel_data_featurized = steel_data_featurized

# %%
# Dropping columns that contain all zeros
# Code from:
# https://stackoverflow.com/questions/21164910/how-do-i-delete-a-column-that-contains-only-zeros-in-pandas
copy_steel_data_featurized = copy_steel_data_featurized.loc[:, (copy_steel_data_featurized != 0).any(axis=0)]

# %%
copy_steel_data_featurized
# Out:
#                                                formula     c    mn    si  \
# 0    Fe0.620C0.000953Mn0.000521Si0.00102Cr0.000110N...  0.02  0.05  0.05
# 1    Fe0.623C0.00854Mn0.000104Si0.000203Cr0.147Ni0....  0.18  0.01  0.01
# 3    Fe0.634C0.000478Mn0.000523Si0.00102Cr0.000111N...  0.01  0.05  0.05
# 4    Fe0.636C0.000474Mn0.000518Si0.00101Cr0.000109N...  0.01  0.05  0.05
# 5    Fe0.636C0.00881Mn0.000203Si0.00972Cr0.135Ni0.0...  0.19  0.02  0.49
# ..                                                 ...   ...   ...   ...
# 307  Fe0.823C0.0176Mn0.00183Si0.000198Cr0.0779Ni0.0...  0.38  0.18  0.01
# 308  Fe0.823Mn0.000618Si0.00101Cr0.0561Ni0.0984Mo0....  0.00  0.06  0.05
# 309  Fe0.825C0.0174Mn0.00175Si0.000201Cr0.0565Ni0.0...  0.37  0.17  0.01
# 310  Fe0.858C0.0191Mn0.00194Si0.000199Cr0.0753Ni0.0...  0.41  0.19  0.01
# 311  Fe0.860C0.0125Mn0.00274Si0.000198Cr0.00439Ni0....  0.27  0.27  0.01
#
#         cr     ni    mo     v     n    nb  ...        Ti         V        Cr  \
# 0     0.01  19.70  2.95  0.01  0.00  0.01  ...  0.018499  0.000112  0.000110
# 1    13.44   0.01  3.01  0.46  0.04  0.01  ...  0.000000  0.005151  0.147026
# 3     0.01  17.70  3.95  0.01  0.00  0.01  ...  0.017611  0.000113  0.000111
# 4     0.01  19.40  1.45  0.01  0.00  0.01  ...  0.018400  0.000112  0.000109
# 5    12.56   0.94  1.96  0.01  0.00  0.01  ...  0.000000  0.000109  0.134886
# ..     ...    ...   ...   ...   ...   ...  ...       ...       ...       ...
# 307   7.27   0.01  3.77  0.96  0.00  0.01  ...  0.000000  0.010500  0.077900
# 308   5.15  10.20  3.20  0.01  0.00  0.01  ...  0.001060  0.000111  0.056101
# 309   5.20   0.01  5.84  1.05  0.00  0.91  ...  0.000000  0.011601  0.056505
# 310   6.99   0.01  5.84  0.92  0.00  0.01  ...  0.000000  0.010103  0.075322
# 311   0.41   8.28  0.49  0.07  0.00  0.01  ...  0.000000  0.000765  0.004392
#
#            Mn        Fe        Co        Ni        Nb        Mo         W
# 0    0.000521  0.619964  0.145992  0.191989  0.000062  0.017599  0.000000
# 1    0.000104  0.623112  0.188034  0.000097  0.000061  0.017903  0.007291
# 3    0.000523  0.634395  0.146091  0.173108  0.000062  0.023715  0.000000
# 4    0.000518  0.635985  0.143997  0.187995  0.000061  0.008600  0.000000
# 5    0.000203  0.635465  0.189840  0.008912  0.000060  0.011390  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 307  0.001830  0.822998  0.046300  0.000095  0.000060  0.021900  0.000000
# 308  0.000618  0.823012  0.000096  0.098401  0.000061  0.018900  0.000000
# 309  0.001750  0.825070  0.046804  0.000096  0.005540  0.034403  0.000000
# 310  0.001941  0.858251  0.000190  0.000095  0.000060  0.034110  0.000000
# 311  0.002741  0.860334  0.036914  0.078631  0.000060  0.002841  0.000000
#
# [303 rows x 32 columns]

# %% [markdown]
# Performing a correlation analysis between all features

# %%
correlation_matrix = copy_steel_data_featurized.corr()

# %%
highly_correlated = correlation_matrix[correlation_matrix > abs(0.8)]

# %%
# Ignoring correlation of feature with itself
highly_correlated = highly_correlated[highly_correlated != 1]
highly_correlated
# Out:
#                          c        mn        si        cr        ni        mo  \
# c                      NaN       NaN       NaN       NaN       NaN       NaN
# mn                     NaN       NaN       NaN       NaN       NaN       NaN
# si                     NaN       NaN       NaN       NaN       NaN       NaN
# cr                     NaN       NaN       NaN       NaN       NaN       NaN
# ni                     NaN       NaN       NaN       NaN       NaN       NaN
# mo                     NaN       NaN       NaN       NaN       NaN       NaN
# v                      NaN       NaN       NaN       NaN       NaN       NaN
# n                      NaN       NaN       NaN       NaN       NaN       NaN
# nb                     NaN       NaN       NaN       NaN       NaN       NaN
# co                     NaN       NaN       NaN       NaN       NaN       NaN
# w                      NaN       NaN       NaN       NaN       NaN       NaN
# al                     NaN       NaN       NaN       NaN       NaN       NaN
# ti                     NaN       NaN       NaN       NaN       NaN       NaN
# yield strength         NaN       NaN       NaN       NaN       NaN       NaN
# tensile strength       NaN       NaN       NaN       NaN       NaN       NaN
# elongation             NaN       NaN       NaN       NaN       NaN       NaN
# C                 0.999847       NaN       NaN       NaN       NaN       NaN
# N                      NaN       NaN       NaN       NaN       NaN       NaN
# Al                     NaN       NaN       NaN       NaN       NaN       NaN
# Si                     NaN       NaN  0.999902       NaN       NaN       NaN
# Ti                     NaN       NaN       NaN       NaN       NaN       NaN
# V                      NaN       NaN       NaN       NaN       NaN       NaN
# Cr                     NaN       NaN       NaN  0.999758       NaN       NaN
# Mn                     NaN  0.999889       NaN       NaN       NaN       NaN
# Fe                     NaN       NaN       NaN       NaN       NaN       NaN
# Co                     NaN       NaN       NaN       NaN       NaN       NaN
# Ni                     NaN       NaN       NaN       NaN  0.999691       NaN
# Nb                     NaN       NaN       NaN       NaN       NaN       NaN
# Mo                     NaN       NaN       NaN       NaN       NaN  0.999828
# W                      NaN       NaN       NaN       NaN       NaN       NaN
#
#                          v         n        nb        co  ...        Ti  \
# c                      NaN       NaN       NaN       NaN  ...       NaN
# mn                     NaN       NaN       NaN       NaN  ...       NaN
# si                     NaN       NaN       NaN       NaN  ...       NaN
# cr                     NaN       NaN       NaN       NaN  ...       NaN
# ni                     NaN       NaN       NaN       NaN  ...       NaN
# mo                     NaN       NaN       NaN       NaN  ...       NaN
# v                      NaN       NaN       NaN       NaN  ...       NaN
# n                      NaN       NaN       NaN       NaN  ...       NaN
# nb                     NaN       NaN       NaN       NaN  ...       NaN
# co                     NaN       NaN       NaN       NaN  ...       NaN
# w                      NaN       NaN       NaN       NaN  ...       NaN
# al                     NaN       NaN       NaN       NaN  ...       NaN
# ti                     NaN       NaN       NaN       NaN  ...  0.999957
# yield strength         NaN       NaN       NaN       NaN  ...       NaN
# tensile strength       NaN       NaN       NaN       NaN  ...       NaN
# elongation             NaN       NaN       NaN       NaN  ...       NaN
# C                      NaN       NaN       NaN       NaN  ...       NaN
# N                      NaN  0.999947       NaN       NaN  ...       NaN
# Al                     NaN       NaN       NaN       NaN  ...       NaN
# Si                     NaN       NaN       NaN       NaN  ...       NaN
# Ti                     NaN       NaN       NaN       NaN  ...       NaN
# V                 0.999959       NaN       NaN       NaN  ...       NaN
# Cr                     NaN       NaN       NaN       NaN  ...       NaN
# Mn                     NaN       NaN       NaN       NaN  ...       NaN
# Fe                     NaN       NaN       NaN       NaN  ...       NaN
# Co                     NaN       NaN       NaN  0.999798  ...       NaN
# Ni                     NaN       NaN       NaN       NaN  ...       NaN
# Nb                     NaN       NaN  0.999988       NaN  ...       NaN
# Mo                     NaN       NaN       NaN       NaN  ...       NaN
# W                      NaN       NaN       NaN       NaN  ...       NaN
#
#                          V        Cr        Mn  Fe        Co        Ni  \
# c                      NaN       NaN       NaN NaN       NaN       NaN
# mn                     NaN       NaN  0.999889 NaN       NaN       NaN
# si                     NaN       NaN       NaN NaN       NaN       NaN
# cr                     NaN  0.999758       NaN NaN       NaN       NaN
# ni                     NaN       NaN       NaN NaN       NaN  0.999691
# mo                     NaN       NaN       NaN NaN       NaN       NaN
# v                 0.999959       NaN       NaN NaN       NaN       NaN
# n                      NaN       NaN       NaN NaN       NaN       NaN
# nb                     NaN       NaN       NaN NaN       NaN       NaN
# co                     NaN       NaN       NaN NaN  0.999798       NaN
# w                      NaN       NaN       NaN NaN       NaN       NaN
# al                     NaN       NaN       NaN NaN       NaN       NaN
# ti                     NaN       NaN       NaN NaN       NaN       NaN
# yield strength         NaN       NaN       NaN NaN       NaN       NaN
# tensile strength       NaN       NaN       NaN NaN       NaN       NaN
# elongation             NaN       NaN       NaN NaN       NaN       NaN
# C                      NaN       NaN       NaN NaN       NaN       NaN
# N                      NaN       NaN       NaN NaN       NaN       NaN
# Al                     NaN       NaN       NaN NaN       NaN       NaN
# Si                     NaN       NaN       NaN NaN       NaN       NaN
# Ti                     NaN       NaN       NaN NaN       NaN       NaN
# V                      NaN       NaN       NaN NaN       NaN       NaN
# Cr                     NaN       NaN       NaN NaN       NaN       NaN
# Mn                     NaN       NaN       NaN NaN       NaN       NaN
# Fe                     NaN       NaN       NaN NaN       NaN       NaN
# Co                     NaN       NaN       NaN NaN       NaN       NaN
# Ni                     NaN       NaN       NaN NaN       NaN       NaN
# Nb                     NaN       NaN       NaN NaN       NaN       NaN
# Mo                     NaN       NaN       NaN NaN       NaN       NaN
# W                      NaN       NaN       NaN NaN       NaN       NaN
#
#                         Nb        Mo         W
# c                      NaN       NaN       NaN
# mn                     NaN       NaN       NaN
# si                     NaN       NaN       NaN
# cr                     NaN       NaN       NaN
# ni                     NaN       NaN       NaN
# mo                     NaN  0.999828       NaN
# v                      NaN       NaN       NaN
# n                      NaN       NaN       NaN
# nb                0.999988       NaN       NaN
# co                     NaN       NaN       NaN
# w                      NaN       NaN  0.999918
# al                     NaN       NaN       NaN
# ti                     NaN       NaN       NaN
# yield strength         NaN       NaN       NaN
# tensile strength       NaN       NaN       NaN
# elongation             NaN       NaN       NaN
# C                      NaN       NaN       NaN
# N                      NaN       NaN       NaN
# Al                     NaN       NaN       NaN
# Si                     NaN       NaN       NaN
# Ti                     NaN       NaN       NaN
# V                      NaN       NaN       NaN
# Cr                     NaN       NaN       NaN
# Mn                     NaN       NaN       NaN
# Fe                     NaN       NaN       NaN
# Co                     NaN       NaN       NaN
# Ni                     NaN       NaN       NaN
# Nb                     NaN       NaN       NaN
# Mo                     NaN       NaN       NaN
# W                      NaN       NaN       NaN
#
# [30 rows x 30 columns]

# %%
features_to_drop = []

# Iterate through upper right triangle of dataframe
for i in range(0, highly_correlated.shape[1] - 1):
    for j in range(i + 1, highly_correlated.shape[1]):
        # If element is not NaN, append column name
        if highly_correlated.iloc[[i], [j]].iloc[0][0] > 0:
            features_to_drop.append((highly_correlated.iloc[:,[j]].columns[0]))

# %%
features_to_drop
# Out:
# ['C',
#  'Mn',
#  'Si',
#  'Cr',
#  'Ni',
#  'Mo',
#  'V',
#  'N',
#  'Nb',
#  'Co',
#  'W',
#  'Al',
#  'Ti',
#  'tensile strength']

# %%
# Drop highly correlated features
low_correlation_df = copy_steel_data_featurized.drop(columns=features_to_drop)

# %%
low_correlation_df
# Out:
#                                                formula     c    mn    si  \
# 0    Fe0.620C0.000953Mn0.000521Si0.00102Cr0.000110N...  0.02  0.05  0.05
# 1    Fe0.623C0.00854Mn0.000104Si0.000203Cr0.147Ni0....  0.18  0.01  0.01
# 3    Fe0.634C0.000478Mn0.000523Si0.00102Cr0.000111N...  0.01  0.05  0.05
# 4    Fe0.636C0.000474Mn0.000518Si0.00101Cr0.000109N...  0.01  0.05  0.05
# 5    Fe0.636C0.00881Mn0.000203Si0.00972Cr0.135Ni0.0...  0.19  0.02  0.49
# ..                                                 ...   ...   ...   ...
# 307  Fe0.823C0.0176Mn0.00183Si0.000198Cr0.0779Ni0.0...  0.38  0.18  0.01
# 308  Fe0.823Mn0.000618Si0.00101Cr0.0561Ni0.0984Mo0....  0.00  0.06  0.05
# 309  Fe0.825C0.0174Mn0.00175Si0.000201Cr0.0565Ni0.0...  0.37  0.17  0.01
# 310  Fe0.858C0.0191Mn0.00194Si0.000199Cr0.0753Ni0.0...  0.41  0.19  0.01
# 311  Fe0.860C0.0125Mn0.00274Si0.000198Cr0.00439Ni0....  0.27  0.27  0.01
#
#         cr     ni    mo     v     n    nb     co     w    al    ti  \
# 0     0.01  19.70  2.95  0.01  0.00  0.01  15.00  0.00  0.15  1.55
# 1    13.44   0.01  3.01  0.46  0.04  0.01  19.46  2.35  0.04  0.00
# 3     0.01  17.70  3.95  0.01  0.00  0.01  15.00  0.00  0.13  1.47
# 4     0.01  19.40  1.45  0.01  0.00  0.01  14.90  0.00  0.13  1.55
# 5    12.56   0.94  1.96  0.01  0.00  0.01  20.10  0.00  0.03  0.00
# ..     ...    ...   ...   ...   ...   ...    ...   ...   ...   ...
# 307   7.27   0.01  3.77  0.96  0.00  0.01   4.90  0.00  0.03  0.00
# 308   5.15  10.20  3.20  0.01  0.00  0.01   0.01  0.00  0.03  0.09
# 309   5.20   0.01  5.84  1.05  0.00  0.91   4.88  0.00  0.03  0.00
# 310   6.99   0.01  5.84  0.92  0.00  0.01   0.02  0.00  0.03  0.00
# 311   0.41   8.28  0.49  0.07  0.00  0.01   3.90  0.00  0.03  0.00
#
#      yield strength  elongation  \
# 0            2411.5         7.0
# 1            1123.1         8.0
# 3            2487.3         9.0
# 4            2249.6         8.5
# 5            1328.3        19.7
# ..              ...         ...
# 307          1722.5         5.0
# 308          1019.0        19.0
# 309          1860.3         3.0
# 310          1812.1         2.0
# 311          1139.7        15.4
#
#                                           composition        Fe
# 0      (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al, Ti)  0.619964
# 1    (Fe, C, Mn, Si, Cr, Ni, Mo, V, N, Nb, Co, W, Al)  0.623112
# 3      (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al, Ti)  0.634395
# 4      (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al, Ti)  0.635985
# 5          (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al)  0.635465
# ..                                                ...       ...
# 307        (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al)  0.822998
# 308       (Fe, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al, Ti)  0.823012
# 309        (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al)  0.825070
# 310        (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al)  0.858251
# 311        (Fe, C, Mn, Si, Cr, Ni, Mo, V, Nb, Co, Al)  0.860334
#
# [303 rows x 18 columns]

# %% [markdown]
# ### <span style="color: red"> Task 4:</span> Setup a private Github repository for this course. Name it MSE403_\<YourName>_\<YourStudentID>. You will be using this repo for homework submission and course project version control. A good place to get started is [here](https://docs.github.com/en/get-started/quickstart/hello-world). You can choose to use the GitHub via the terminal (<ins>recommanded</ins>), the [GitHub desktop app](https://desktop.github.com/), or the online GitHub platform. After setting up your repo, make sure to share your repo with [Jae]() and [Xiao](https://github.com/xshang93) by adding us as collabrators.

# %%
# Done
